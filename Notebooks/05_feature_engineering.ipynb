# %% [markdown]
# Contains:
#
# Create new variables like:
#
# - House Age
# - Remodel Age
# - Total Bathrooms
# - Total Living Area
# - Total Porch Area
# - Total Outdoor Area
#
# Evaluate whether they improve performance.
